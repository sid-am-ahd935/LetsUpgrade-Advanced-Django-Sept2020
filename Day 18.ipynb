# %%
import os,re
from argparse import ArgumentParser as AP

version = 1.91

G = '\u001b[100;106m' #Green Background
Y = '\033[93m' #Yellow
R = '\033[91m' #Red
W = '\033[0m'  #Colour Reset Code, Here White
P = '\u001b[95m' #Pink
C = '\u001b[36m' #Cyan

#---------------------------------------------
##To Print Beautifully, Is Called By All Funcs
def Print(func,args):
	word = args[0]
	dir = args[1]
	
	print("\n" + "—"*65)
	print("The Word Searched For:",word)
	print("-"*40)
	found, not_working = func(word,dir)
	
	if found == 0:
		print(f"\nNo Files Containing {R}{word}{W} Found")
	else:
		print(f"\nTotal File(s) Found Containing {R}{word}{W}: {G} {found} {W}")
	
	if len(not_working) > 0:
		print("\n" + "*"*65 + "\n")
		print("File(s) Not Accessible:\n")
		for i in range(len(not_working)):
			print(f"{i+1}) {not_working[i]} Can Not Be Processed.")
		
	print("\n" + "—"*65)
	

#---------------------------------------------
#Word Search With Sensitive Case 
#Including Line Number

def func_m(word,dir):
	found = 0
	not_working = []
	
	for files in os.walk(dir):
		cwd = (files[0])
		
		#Prints Files Containing Word
		#And Increment Number Of Founds
		#While Collecting Non-Accessible Files
		for each in files[2]:
			try:
				f= open(f"{cwd}/{each}", 'r')
				data = f.read()
				f.close()
			except:
				not_working.append(each)
				continue
			#Collecting Non-Accessible Files
				
			#Searching For Word Inside File
			m = re.search(word, data)
			if m:
				found +=1
				line= data[:m.start()].count("\n") + 1
				#If Count=0, No Lines Before m And m.group() Will Be In Line 1
				print(f"{R}{m.group()}{W} Found In {C}{cwd}/{each}{W} In Line {P}{line}{W}")
				#os.getcwd() = files[0]
	
	#When All Files Are Accessed Or 
	#No Files Are Available,
	#Return The No. Of Found And
	#Non Accessible File Names
	return found, not_working
	
	
#---------------------------------------------
#Word Search With Sensitive Case 
#Without Line Number

def func_s(word,dir):
	not_working = []
	found = 0
	
	for files in os.walk(dir):
		cwd = (files[0])
		
		#Prints Files Containing Word
		#And Increment Number Of Founds
		#While Collecting Non-Accessible Files
		for each in files[2]:
			try:
				f= open(cwd+"/"+each, 'r')
				data = f.read()
				f.close()
			except:
				not_working.append(each)
				continue
			#Collecting Non-Accessible Files
				
			#Searching For Word Inside File
			m = re.search(word, data)
			if m:
				found += 1
				print(f"{R}{m.group()}{W} Found In {C}{cwd}/{each}{W}")
				#os.getcwd() = files[0]
	
	#When All Files Are Accessed Or 
	#No Files Are Available,
	#Return The No. Of Found And
	#Non Accessible File Names
	return found, not_working

#---------------------------------------------
#Recursively Searching Through Files 
#For Case Sensitive Word

def func_r(word,dir,found=0,not_working=[]):
	
	#To Get All Dirs Available
	dirs = [i for i in os.listdir(dir) if os.path.isdir(dir+"/"+i)]
	#To Get All Files Available
	files = [i for i in os.listdir(dir) if os.path.isfile(dir+"/"+i)]
	
	#Accessing The Deepest Folder First
	#Calls Itself And Prints Files Containing
	#Word And Increment Number Of Founds
	#While Collecting Non-Accessible Files
	if len(dirs) > 0:
		for i in dirs:
			path = (dir+"/"+i)
			found,not_working = func_r(word,path,found,not_working)
	
	#Printing The Accessible Files 
	#Containing Word
	#From The Bottom To The Top
	#Using Recursion
	for each in files:
		try:
			f= open(dir+"/"+each, 'r')
			data = f.read()
			f.close()
		except:
			#Collecting Non-Accessible Files
			not_working.append(each)
			continue
		
		#Searching For The Word Inside File
		m = re.search(word, data)
		if m:
			#When Word Is Found,
			#Increase Count
			found += 1
			#And Print
			lin=data[:m.start()].count('\n')+1
			print(f"{R}{m.group()}{W} Found In {C}{dir}/{each}{W} In Line {P}{lin}{W}")
			#os.getcwd() = files[0]
	
	#When All Files Are Accessed Or 
	#No Files Are Available,
	#Return The No. Of Found And
	#Non Accessible File Names
	return found, not_working
	
	
#---------------------------------------------
#Word Search With Insensitive Case & Line No.

def func_mi(word,dir):
	found = 0
	not_working = []
	
	for files in os.walk(dir):
		cwd = (files[0])
		
		#Prints Files Containing Word
		#And Increment Number Of Founds
		#While Collecting Non-Accessible Files
		for each in files[2]:
			try:
				f= open(f"{cwd}/{each}", 'r')
				data = f.read()
				f.close()
			except:
				not_working.append(each)
				continue
			#Collecting Non-Accessible Files
				
			#Searching For Word Inside File
			m = re.search(word, data, re.I)
			if m:
				found +=1
				line= data[:m.start()].count("\n") + 1
				#If Count=0, No Lines Before m And m.group() Will Be In Line 1
				print(f"{R}{m.group()}{W} Found In {C}{cwd}/{each}{W} In Line {P}{line}{W}")
				#os.getcwd() = files[0]
	
	#When All Files Are Accessed Or 
	#No Files Are Available,
	#Return The No. Of Found And
	#Non Accessible File Names
	return found, not_working
	
	
#---------------------------------------------
#Search With Insensitive Case Without Line No.

def func_si(word,dir):
	not_working = []
	found = 0
	
	for files in os.walk(dir):
		cwd = (files[0])
		
		#Prints Files Containing Word
		#And Increment Number Of Founds
		#While Collecting Non-Accessible Files
		for each in files[2]:
			try:
				f= open(cwd+"/"+each, 'r')
				data = f.read()
				f.close()
			except:
				not_working.append(each)
				continue
			#Collecting Non-Accessible Files
				
			#Searching For Word Inside File
			m = re.search(word, data, re.I)
			if m:
				found += 1
				print(f"{R}{m.group()}{W} Found In {C}{cwd}/{each}{W}")
				#os.getcwd() = files[0]
	
	#When All Files Are Accessed Or 
	#No Files Are Available,
	#Return The No. Of Found And
	#Non Accessible File Names
	return found, not_working

#---------------------------------------------
#Seaching Word Through Files Recursively
#For Finding Case Insensitive Word

def func_ri(word,dir,found=0,not_working=[]):
	
	#To Get All Dirs Available
	dirs = [i for i in os.listdir(dir) if os.path.isdir(dir+"/"+i)]
	#To Get All Files Available
	files = [i for i in os.listdir(dir) if os.path.isfile(dir+"/"+i)]
	
	#Accessing The Deepest Folder First
	#Calls Itself And Prints Files Containing
	#Word And Increment Number Of Founds
	#While Collecting Non-Accessible Files
	if len(dirs) > 0:
		for i in dirs:
			path = (dir+"/"+i)
			found,not_working = func_ri(word,path,found,not_working)
	
	#Printing The Accessible Files 
	#Containing Word
	#From The Bottom To The Top
	#Using Recursion
	for each in files:
		try:
			f= open(dir+"/"+each, 'r')
			data = f.read()
			f.close()
		except:
			#Collecting Non-Accessible Files
			not_working.append(each)
			continue
		
		#Searching For The Word Inside File
		m = re.search(word, data, re.I)
		if m:
			#When Word Is Found,
			#Increase Count
			found += 1
			#And Print
			lin=data[:m.start()].count('\n')+1
			print(f"{R}{m.group()}{W} Found In {C}{dir}/{each}{W} In Line {P}{lin}{W}")
			#os.getcwd() = files[0]
	
	#When All Files Are Accessed Or 
	#No Files Are Available,
	#Return The No. Of Found And
	#Non Accessible File Names
	return found, not_working
	
	
#---------------------------------------------
##Main Function To Run The Whole Program

def main():
	a = AP(description= "Finds First Occurence Of The Searched [str] Word In Text Files Provided By [DIR] (RegEx Available) (Current Directory= '.')")
	
	
	a.add_argument("-v", dest= "version", default= None, action= 'store_true', help= 'Print Current Version Number Of This Program')
	a.add_argument("-m", nargs= 2, metavar= ('[str]', '[DIR]'), help = 'To Get Files With Line Number Containing str')
	a.add_argument("-s", nargs= 2, metavar= ('[str]', '[DIR]'), help = 'To Get Only The Files Containing str')
	a.add_argument("-r", nargs= 2, metavar= ('[str]', '[DIR]'), help = 'To Search Like -m Option In Recursive Order')
	a.add_argument("-mi", nargs= 2, metavar= ('[str]', '[DIR]'), help = '-m Option With Case Insensitive')
	a.add_argument("-si", nargs= 2, metavar= ('[str]', '[DIR]'), help = '-s Option With Case Insensitive')
	a.add_argument("-ri", nargs= 2, metavar= ('[str]', '[DIR]'), help = '-r Option With Case Insensitive')
	
	#a.print_help()
	args = a.parse_args()
	#"-mi Import /storage/emulated/0/Python".split())
	if args.version:
		print("—"*65)
		print("\nCurrent Version: %.3f\n"%version)
		print("—"*65)
	
	if args.m: 	Print(func_m,args.m)
	
	if args.s: 	Print(func_s,args.s)
		
	if args.r: 	Print(func_r,args.r)
		
	if args.mi:	Print(func_mi,args.mi)
	
	if args.si:	Print(func_si,args.si)
		
	if args.ri:	Print(func_ri,args.ri)
	
#---------------------------------------------
#Running The Program
if __name__ == "__main__":
    main()
# Out:
# -ri Os /storage/emulated/0/Python
# $ python Day\ 18\ Assignment\ 1.py -ri Os /storage/emulated/0/Python
#
# —————————————————————————————————————————————————————————————————
# The Word Searched For: Os
# ----------------------------------------
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/Addition Assignment.cxx In Line 4
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/TrianglePattern Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/Pointers Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/SwapPointerValue Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/MatrixAddition Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/DoublePointer(P2P) Assignment.cxx In Line 5
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/FunctionPointer(F2P).cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/FunctionPointer(F2P) Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/Morse Code Converter.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/GreatestNumber Assignment.cxx In Line 3
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/EvenOdd Assignment.cxx In Line 3
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/RecursiveFactorial Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/Factorial Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/FibonacciSeries Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/FindPrime Assignment.cxx In Line 3
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/StudentReportCardArray Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/MatrixScalarMultiplication Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/PyramidPattern Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/MatrixVectorMultiplication Assignment.cxx In Line 1
# os Found In /storage/emulated/0/Python/testdir/CxxDroidPrograms/LargestNumberFunction Assignment.cxx In Line 1
# Os Found In /storage/emulated/0/Python/LetsUpgrade Python/.ipynb_checkpoints/Day 5 Hydra-checkpoint.ipynb In Line 22
# os Found In /storage/emulated/0/Python/LetsUpgrade Python/.ipynb_checkpoints/Day 10-checkpoint.ipynb In Line 79
# os Found In /storage/emulated/0/Python/LetsUpgrade Python/.ipynb_checkpoints/Day 13-checkpoint.ipynb In Line 43
# Os Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 5 Hydra Assignment.py In Line 5
# os Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 10 Assignment 1.py In Line 38
# os Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 13 Assignment 1.py In Line 3
# os Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 13 Assignment 2.py In Line 3
# Os Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 5 Hydra.ipynb In Line 22
# os Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 10.ipynb In Line 79
# os Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 13.ipynb In Line 43
# os Found In /storage/emulated/0/Python/See Files/AllTypesOfPrimeNumberFunctions.py In Line 58
# os Found In /storage/emulated/0/Python/See Files/CLIRecursion.py In Line 2
# os Found In /storage/emulated/0/Python/See Files/Dummy Finder Indexer.py In Line 1
# os Found In /storage/emulated/0/Python/See Files/DummySeeProgram.py In Line 5
# OS Found In /storage/emulated/0/Python/See Files/IP Input File.txt In Line 8
# os Found In /storage/emulated/0/Python/See Files/LearnAttribute.py In Line 22
# os Found In /storage/emulated/0/Python/See Files/LiveWebsiteChecker.py In Line 4
# os Found In /storage/emulated/0/Python/See Files/SolvedOSDoubts.py In Line 1
# os Found In /storage/emulated/0/Python/See Files/timeclone.py In Line 14
# os Found In /storage/emulated/0/Python/See Files/TimeZoneFinder.py In Line 20
# os Found In /storage/emulated/0/Python/See Files/Understand_finally_Block.py In Line 19
# os Found In /storage/emulated/0/Python/AllTypesOfPrimeNumberFunctions.py In Line 58
# os Found In /storage/emulated/0/Python/Understand_finally_Block.py In Line 19
# os Found In /storage/emulated/0/Python/TimeZoneFinder.py In Line 20
# os Found In /storage/emulated/0/Python/timeclone.py In Line 14
# os Found In /storage/emulated/0/Python/LiveWebsiteChecker.py In Line 4
# os Found In /storage/emulated/0/Python/SolvedOSDoubts.py In Line 1
# os Found In /storage/emulated/0/Python/Dummy Finder Indexer.py In Line 1
# os Found In /storage/emulated/0/Python/CLIRecursion.py In Line 2
# OS Found In /storage/emulated/0/Python/IP Input File.txt In Line 8
# os Found In /storage/emulated/0/Python/LearnAttribute.py In Line 22
# os Found In /storage/emulated/0/Python/DummySeeProgram.py In Line 5
# os Found In /storage/emulated/0/Python/forVSwhileTimeBattle.py In Line 23
# os Found In /storage/emulated/0/Python/See Program.py In Line 1
#
# Total File(s) Found Containing Os:  54
#
# *****************************************************************
#
# File(s) Not Accessible:
#
# 1) parsing.cpython-38.pyc Can Not Be Processed.
# 2) Nodes.cpython-38.pyc Can Not Be Processed.
# 3) __init__.cpython-38.pyc Can Not Be Processed.
# 4) A1.cpython-38.pyc Can Not Be Processed.
# 5) B1.cpython-38.pyc Can Not Be Processed.
# 6) Day 13 Assignment 1.cpython-38.pyc Can Not Be Processed.
# 7) Most Effective Prime Number Program.pdf Can Not Be Processed.
# 8) sample.balle Can Not Be Processed.
#
# —————————————————————————————————————————————————————————————————
#
# [Program Finished]
#
# -mi ImPoRT /storage/emulated/0/Python
# $ python Day\ 18\ Assignment\ 1.py -mi ImPoRT /storage/emulated/0/Python
#
# —————————————————————————————————————————————————————————————————
# The Word Searched For: ImPoRT
# ----------------------------------------
# import Found In /storage/emulated/0/Python/AllTypesOfPrimeNumberFunctions.py In Line 1
# import Found In /storage/emulated/0/Python/Importing_testpack_AsPackage.py In Line 1
# import Found In /storage/emulated/0/Python/PickleStuff.py In Line 1
# import Found In /storage/emulated/0/Python/EpochAndHumanTimeConverter.py In Line 1
# import Found In /storage/emulated/0/Python/LocalvsGMTtime.py In Line 1
# import Found In /storage/emulated/0/Python/TimeZoneFinder.py In Line 7
# import Found In /storage/emulated/0/Python/timeclone.py In Line 3
# import Found In /storage/emulated/0/Python/LearnConfig.py In Line 1
# import Found In /storage/emulated/0/Python/LiveWebsiteChecker.py In Line 4
# import Found In /storage/emulated/0/Python/SolvedOSDoubts.py In Line 1
# import Found In /storage/emulated/0/Python/p2.py In Line 1
# import Found In /storage/emulated/0/Python/Regex.py In Line 1
# import Found In /storage/emulated/0/Python/p1.py In Line 1
# import Found In /storage/emulated/0/Python/p3.py In Line 1
# import Found In /storage/emulated/0/Python/Dummy Finder Indexer.py In Line 1
# import Found In /storage/emulated/0/Python/CLIRecursion.py In Line 1
# import Found In /storage/emulated/0/Python/FuncRecursion.py In Line 1
# import Found In /storage/emulated/0/Python/ObjectRecursion.py In Line 1
# import Found In /storage/emulated/0/Python/RandomTextGeneratorForIP.py In Line 4
# import Found In /storage/emulated/0/Python/LearnArgParse.py In Line 1
# import Found In /storage/emulated/0/Python/IPExtractorFromInputFile.py In Line 6
# import Found In /storage/emulated/0/Python/DummySeeProgram.py In Line 5
# import Found In /storage/emulated/0/Python/forVSwhileTimeBattle.py In Line 1
# import Found In /storage/emulated/0/Python/ANSI Colour Coding In CLI Python.py In Line 36
# import Found In /storage/emulated/0/Python/Lowest Size MP4 Video Downloader From YouTube PyTube.py In Line 1
# import Found In /storage/emulated/0/Python/See Program.py In Line 1
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 7 Assignment 1.py In Line 127
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 9 Assignment 1.py In Line 1
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 10 Assignment 1.py In Line 1
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 13 Assignment 1.py In Line 3
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 13 Assignment 2.py In Line 3
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 7.ipynb In Line 198
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 9.ipynb In Line 40
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 10.ipynb In Line 42
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 13.ipynb In Line 43
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 16 Assignment 1.py In Line 5
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/Day 16.ipynb In Line 35
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/.ipynb_checkpoints/Day 7-checkpoint.ipynb In Line 198
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/.ipynb_checkpoints/Day 9-checkpoint.ipynb In Line 40
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/.ipynb_checkpoints/Day 10-checkpoint.ipynb In Line 42
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/.ipynb_checkpoints/Day 13-checkpoint.ipynb In Line 43
# import Found In /storage/emulated/0/Python/LetsUpgrade Python/.ipynb_checkpoints/Day 16-checkpoint.ipynb In Line 35
# import Found In /storage/emulated/0/Python/See Files/AllTypesOfPrimeNumberFunctions.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/CLIRecursion.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/Dummy Finder Indexer.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/DummySeeProgram.py In Line 5
# import Found In /storage/emulated/0/Python/See Files/EpochAndHumanTimeConverter.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/FuncRecursion.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/Importing_testpack_AsPackage.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/IPExtractorFromInputFile.py In Line 6
# import Found In /storage/emulated/0/Python/See Files/LearnArgParse.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/LearnConfig.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/LiveWebsiteChecker.py In Line 4
# import Found In /storage/emulated/0/Python/See Files/LocalvsGMTtime.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/ObjectRecursion.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/p1.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/p2.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/p3.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/PickleStuff.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/RandomTextGeneratorForIP.py In Line 4
# import Found In /storage/emulated/0/Python/See Files/Regex.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/SolvedOSDoubts.py In Line 1
# import Found In /storage/emulated/0/Python/See Files/timeclone.py In Line 3
# import Found In /storage/emulated/0/Python/See Files/TimeZoneFinder.py In Line 7
#
# Total File(s) Found Containing ImPoRT:  64
#
# *****************************************************************
#
# File(s) Not Accessible:
#
# 1) Most Effective Prime Number Program.pdf Can Not Be Processed.
# 2) sample.balle Can Not Be Processed.
# 3) parsing.cpython-38.pyc Can Not Be Processed.
# 4) Nodes.cpython-38.pyc Can Not Be Processed.
# 5) __init__.cpython-38.pyc Can Not Be Processed.
# 6) A1.cpython-38.pyc Can Not Be Processed.
# 7) B1.cpython-38.pyc Can Not Be Processed.
# 8) Day 13 Assignment 1.cpython-38.pyc Can Not Be Processed.
#
# —————————————————————————————————————————————————————————————————
#
# [Program Finished]
#
# -s Hello /storage/emulated/0/Python
# $ python Day\ 18\ Assignment\ 1.py -s Hello /storage/emulated/0/Python
#
# —————————————————————————————————————————————————————————————————
# The Word Searched For: Hello
# ----------------------------------------
# Hello Found In /storage/emulated/0/Python/amanda
# Hello Found In /storage/emulated/0/Python/klick
# Hello Found In /storage/emulated/0/Python/racecar
# Hello Found In /storage/emulated/0/Python/madam
# Hello Found In /storage/emulated/0/Python/CLIRecursion.py
# Hello Found In /storage/emulated/0/Python/FuncRecursion.py
# Hello Found In /storage/emulated/0/Python/ObjectRecursion.py
# Hello Found In /storage/emulated/0/Python/Learnsuper.py
# Hello Found In /storage/emulated/0/Python/3TypesOfMethods.py
# Hello Found In /storage/emulated/0/Python/See Files/amanda
# Hello Found In /storage/emulated/0/Python/See Files/CLIRecursion.py
# Hello Found In /storage/emulated/0/Python/See Files/FuncRecursion.py
# Hello Found In /storage/emulated/0/Python/See Files/klick
# Hello Found In /storage/emulated/0/Python/See Files/madam
# Hello Found In /storage/emulated/0/Python/See Files/ObjectRecursion.py
# Hello Found In /storage/emulated/0/Python/See Files/racecar
#
# Total File(s) Found Containing Hello:  16
#
# *****************************************************************
#
# File(s) Not Accessible:
#
# 1) Most Effective Prime Number Program.pdf Can Not Be Processed.
# 2) sample.balle Can Not Be Processed.
# 3) parsing.cpython-38.pyc Can Not Be Processed.
# 4) Nodes.cpython-38.pyc Can Not Be Processed.
# 5) __init__.cpython-38.pyc Can Not Be Processed.
# 6) A1.cpython-38.pyc Can Not Be Processed.
# 7) B1.cpython-38.pyc Can Not Be Processed.
# 8) Day 13 Assignment 1.cpython-38.pyc Can Not Be Processed.
#
# —————————————————————————————————————————————————————————————————
#
# [Program Finished]
