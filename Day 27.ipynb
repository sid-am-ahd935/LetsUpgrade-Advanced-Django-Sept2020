# %%
import datetime
import sys

#Due To Performance Issues,
#The Device Only Runs Upto 1 with 7 0's

def generated(main_list):
	t1 = datetime.datetime.now()
	list1 = (each**2 for each in main_list)
	for each in list1:
		each
	t2 = datetime.datetime.now()
	print ("\nTime Taken While Using Generator:", t2-t1)
	print ("Memory Taken By Generator:", sys.getsizeof(list1))

def listed(main_list):
	t1 = datetime.datetime.now()
	list1 = [each**2 for each in main_list]
	for each in list1:
		each
	t2 = datetime.datetime.now()
	print ("\nTime Taken While Using List", t2-t1)
	print ("Memory Taken By List:", sys.getsizeof(list1))


while True:
	num = input('\n\nEnter Size Of List: ')
	if not num.isnumeric(): break
	
	num = int(num)

	list1 = list(range(num))
	
	generated(list1)
	listed(list1)

print("Program Ended")
# Out:
# Enter Size Of List: 1
#
# Time Taken While Using Generator: 0:00:00.000067
# Memory Taken By Generator: 56
#
# Time Taken While Using List 0:00:00.000064
# Memory Taken By List: 44
#
#
# Enter Size Of List: 10
#
# Time Taken While Using Generator: 0:00:00.000080
# Memory Taken By Generator: 56
#
# Time Taken While Using List 0:00:00.000080
# Memory Taken By List: 92
#
#
# Enter Size Of List: 100
#
# Time Taken While Using Generator: 0:00:00.000194
# Memory Taken By Generator: 56
#
# Time Taken While Using List 0:00:00.000185
# Memory Taken By List: 452
#
#
# Enter Size Of List: 1000
#
# Time Taken While Using Generator: 0:00:00.001743
# Memory Taken By Generator: 56
#
# Time Taken While Using List 0:00:00.001670
# Memory Taken By List: 4508
#
#
# Enter Size Of List: 10000
#
# Time Taken While Using Generator: 0:00:00.016975
# Memory Taken By Generator: 56
#
# Time Taken While Using List 0:00:00.020975
# Memory Taken By List: 43808
#
#
# Enter Size Of List: 100000
#
# Time Taken While Using Generator: 0:00:00.216272
# Memory Taken By Generator: 56
#
# Time Taken While Using List 0:00:00.180949
# Memory Taken By List: 412228
#
#
# Enter Size Of List: 1000000
#
# Time Taken While Using Generator: 0:00:02.012174
# Memory Taken By Generator: 56
#
# Time Taken While Using List 0:00:01.880392
# Memory Taken By List: 4348728
#
#
# Enter Size Of List: 10000000
#
# Time Taken While Using Generator: 0:00:20.221608
# Memory Taken By Generator: 56
#
# Time Taken While Using List 0:00:18.598124
# Memory Taken By List: 40764024
#
#
# Enter Size Of List: exit
# Program Ended
