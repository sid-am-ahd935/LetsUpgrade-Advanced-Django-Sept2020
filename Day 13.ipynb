# %%
#File Name Changer Through Config Input

import os
from configparser import ConfigParser as CP

#Assuming The Python File Is With The File Input.ini For Input
config = CP()
config.read("Day 13 Assignment 1 Input.ini")
#print((config.sections()))
#For Getting Full Path To File Directory
Folder = config.get("INPUT","current_path")

#To Get The File Extensions To Rename
ext1 = config.get("INPUT","From")

#To Rename The File Extensions Into
ext2 = config.get("INPUT","To")

#Changing Path Into The Given Directory
os.chdir(Folder)

#for each in os.listdir():
#	print(each)	
#print("\n")

#Iterating Through Every File
i = 0
for each in os.listdir():
	#Checking If Required To Change Extension
	if (each.rsplit(".",1)[1] == ext1):
		#Storing The New Name For Changing
		str1 = each.rsplit(".",1)[0] + "." + ext2
		print(f"Changed {each} to {str1}")
		#Changing Extension
		os.rename(each,str1)
		i += 1

print("\nTotal File(s) Renamed: %d,\nFrom [.%s] to [.%s]"%(i,ext1,ext2))

#for each in os.listdir():
#	print(each)
# Out:
# Changed TemperatureConversion Assignment.c to TemperatureConversion Assignment.cxx
# Changed Addition Assignment.c to Addition Assignment.cxx
# Changed TrianglePattern Assignment.c to TrianglePattern Assignment.cxx
# Changed Pointers Assignment.c to Pointers Assignment.cxx
# Changed SwapPointerValue Assignment.c to SwapPointerValue Assignment.cxx
# Changed MatrixAddition Assignment.c to MatrixAddition Assignment.cxx
# Changed MatrixVectorMultiplication Assignment.c to MatrixVectorMultiplication Assignment.cxx
# Changed DoublePointer(P2P) Assignment.c to DoublePointer(P2P) Assignment.cxx
# Changed FunctionPointer(F2P).c to FunctionPointer(F2P).cxx
# Changed FunctionPointer(F2P) Assignment.c to FunctionPointer(F2P) Assignment.cxx
# Changed Morse Code Converter.c to Morse Code Converter.cxx
# Changed GreatestNumber Assignment.c to GreatestNumber Assignment.cxx
# Changed EvenOdd Assignment.c to EvenOdd Assignment.cxx
# Changed RecursiveFactorial Assignment.c to RecursiveFactorial Assignment.cxx
# Changed Factorial Assignment.c to Factorial Assignment.cxx
# Changed FibonacciSeries Assignment.c to FibonacciSeries Assignment.cxx
# Changed FindPrime Assignment.c to FindPrime Assignment.cxx
# Changed StudentReportCardArray Assignment.c to StudentReportCardArray Assignment.cxx
# Changed MatrixScalarMultiplication Assignment.c to MatrixScalarMultiplication Assignment.cxx
# Changed PyramidPattern Assignment.c to PyramidPattern Assignment.cxx
# Changed LargestNumberFunction Assignment.c to LargestNumberFunction Assignment.cxx
#
# Total File(s) Renamed: 21,
# From [.c] to [.cxx]

# %%
#Dummy Finder Program Assignment

import os
from collections import defaultdict as ddict

#Creating Two Default Dicts
#Each For Files And Directories
file_dict = ddict(list)
dir_dict = ddict(list)

#Indexing All Available Folders And Files
i = 0 #For Counting Total Dir(s)
j = 0 #For Counting Total Files(s)
for r,d,f in os.walk("/storage/emulated/0"):
	for each in d:
		dir_dict[each].append(r)
		i += 1
	for each in f:
		file_dict[each].append(r)
		j += 1


print("\\"*4, "Indexing Done", "/"*4)
print("Dir(s) Indexed:",i)
print("File(s) Indexed:",j)


#User Input To Search
print("\nEnter The File Name, Initial Part Is Also Accepted If Full Name Not Available:-")
#name = input("Enter:")
name = " Assignment"
print("Enter:",name)
i = 0 #For Counting Found Dir(s)
j = 0 #For Counting Found File(s)

print("\n"+"*"*15)
print("Dir(s) Found:")
print("*"*15,"\n")
#Searching Through Dir(s) And Printing Them
for k,v in dir_dict.items():
	if name.lower() in k.lower():
		for each in v:
			i += 1
			print("*"*60)
			print(f"\n{i})\n\n"+(each+"/"+k).replace(" ","_"),"\n")
			#Printing Full Path, " " As "_"
			
print("*"*60,"\n")


print("\n"+"*"*15)
print("File(s) Found:")
print("*"*15,"\n")
#Searching Through Files(s) And Printing Them
for k,v in file_dict.items():
	if name.lower() in k.lower():
		for each in v:
			j += 1
			print("*"*60)
			print(f"\n{j})\n\n"+(each+"/"+k).replace(" ","_"),"\n")
			#Printing Full Path With " " As "_"
			
print("*"*60,"\n\n")

#A Lot Of Print Statements Are 
#For Beautification Purposes Only
print("Total Dir(s) Found:",i)
print("Total File(s) Found:",j)

#And Along With The Printing, We Can Add
#TheIndexes Of The Found Files In A Dict
#With Their Path As Values
#To Use It For Easy Accessible
#Like Copy Paste Or Simply Opening It
# Out:
# \\\\ Indexing Done ////
# Dir(s) Indexed: 744
# File(s) Indexed: 12433
#
# Enter The File Name, Initial Part Is Also Accepted If Full Name Not Available:-
# Enter:  Assignment
#
# ***************
# Dir(s) Found:
# ***************
#
# ************************************************************
#
#
# ***************
# File(s) Found:
# ***************
#
# ************************************************************
#
# 1)
#
# /storage/emulated/0/WhatsApp/Media/WhatsApp_Documents/Private/EEN_WORKSHOP_LAB_ASSIGNMENT_REPORT.pdf
#
# ************************************************************
#
# 2)
#
# /storage/emulated/0/WhatsApp/Media/WhatsApp_Documents/Private/EEN_WORKSHOP_LAB_ASSIGNMENT_REPORT-1.pdf
#
# ************************************************************
#
# 3)
#
# /storage/emulated/0/WhatsApp/Media/WhatsApp_Documents/Private/ECE_WORKSHOP_LAB_ASSIGNMENT_REPORT.pdf
#
# ************************************************************
#
# 4)
#
# /storage/emulated/0/Python/Lambda_Of_Day_3_Assignment_2.py
#
# ************************************************************
#
# 5)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/Addition_Assignment.cxx
#
# ************************************************************
#
# 6)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/TrianglePattern_Assignment.cxx
#
# ************************************************************
#
# 7)
#
# /storage/emulated/0/CxxDroidPrograms/TrianglePattern_Assignment.cxx
#
# ************************************************************
#
# 8)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/Pointers_Assignment.cxx
#
# ************************************************************
#
# 9)
#
# /storage/emulated/0/CxxDroidPrograms/Pointers_Assignment.cxx
#
# ************************************************************
#
# 10)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/SwapPointerValue_Assignment.cxx
#
# ************************************************************
#
# 11)
#
# /storage/emulated/0/CxxDroidPrograms/SwapPointerValue_Assignment.cxx
#
# ************************************************************
#
# 12)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/MatrixAddition_Assignment.cxx
#
# ************************************************************
#
# 13)
#
# /storage/emulated/0/CxxDroidPrograms/MatrixAddition_Assignment.cxx
#
# ************************************************************
#
# 14)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/DoublePointer(P2P)_Assignment.cxx
#
# ************************************************************
#
# 15)
#
# /storage/emulated/0/CxxDroidPrograms/DoublePointer(P2P)_Assignment.cxx
#
# ************************************************************
#
# 16)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/FunctionPointer(F2P)_Assignment.cxx
#
# ************************************************************
#
# 17)
#
# /storage/emulated/0/CxxDroidPrograms/FunctionPointer(F2P)_Assignment.cxx
#
# ************************************************************
#
# 18)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/GreatestNumber_Assignment.cxx
#
# ************************************************************
#
# 19)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/EvenOdd_Assignment.cxx
#
# ************************************************************
#
# 20)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/RecursiveFactorial_Assignment.cxx
#
# ************************************************************
#
# 21)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/Factorial_Assignment.cxx
#
# ************************************************************
#
# 22)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/FibonacciSeries_Assignment.cxx
#
# ************************************************************
#
# 23)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/FindPrime_Assignment.cxx
#
# ************************************************************
#
# 24)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/StudentReportCardArray_Assignment.cxx
#
# ************************************************************
#
# 25)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/MatrixScalarMultiplication_Assignment.cxx
#
# ************************************************************
#
# 26)
#
# /storage/emulated/0/CxxDroidPrograms/MatrixScalarMultiplication_Assignment.cxx
#
# ************************************************************
#
# 27)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/PyramidPattern_Assignment.cxx
#
# ************************************************************
#
# 28)
#
# /storage/emulated/0/CxxDroidPrograms/PyramidPattern_Assignment.cxx
#
# ************************************************************
#
# 29)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/TemperatureConversion_Assignment.cxx
#
# ************************************************************
#
# 30)
#
# /storage/emulated/0/CxxDroidPrograms/TemperatureConversion_Assignment.cxx
#
# ************************************************************
#
# 31)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/MatrixVectorMultiplication_Assignment.cxx
#
# ************************************************************
#
# 32)
#
# /storage/emulated/0/CxxDroidPrograms/MatrixVectorMultiplication_Assignment.cxx
#
# ************************************************************
#
# 33)
#
# /storage/emulated/0/Python/testdir/CxxDroidPrograms/LargestNumberFunction_Assignment.cxx
#
# ************************************************************
#
# 34)
#
# /storage/emulated/0/CxxDroidPrograms/Addition_Assignment.c
#
# ************************************************************
#
# 35)
#
# /storage/emulated/0/CxxDroidPrograms/EvenOdd_Assignment.c
#
# ************************************************************
#
# 36)
#
# /storage/emulated/0/CxxDroidPrograms/Factorial_Assignment.c
#
# ************************************************************
#
# 37)
#
# /storage/emulated/0/CxxDroidPrograms/FindPrime_Assignment.c
#
# ************************************************************
#
# 38)
#
# /storage/emulated/0/CxxDroidPrograms/GreatestNumber_Assignment.c
#
# ************************************************************
#
# 39)
#
# /storage/emulated/0/CxxDroidPrograms/LargestNumberFunction_Assignment.c
#
# ************************************************************
#
# 40)
#
# /storage/emulated/0/CxxDroidPrograms/RecursiveFactorial_Assignment.c
#
# ************************************************************
#
# 41)
#
# /storage/emulated/0/CxxDroidPrograms/FibonacciSeries_Assignment.c
#
# ************************************************************
#
# 42)
#
# /storage/emulated/0/CxxDroidPrograms/StudentReportCardArray_Assignment.c
#
# ************************************************************
#
# 43)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_3_Assignment_2.py
#
# ************************************************************
#
# 44)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_5_Hydra_Assignment.py
#
# ************************************************************
#
# 45)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_3_Assignment_3.py
#
# ************************************************************
#
# 46)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_3_Assignment_1.py
#
# ************************************************************
#
# 47)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_3_Assignment_4.py
#
# ************************************************************
#
# 48)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_7_Assignment_1.py
#
# ************************************************************
#
# 49)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_9_Assignment_1.py
#
# ************************************************************
#
# 50)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_10_Assignment_1.py
#
# ************************************************************
#
# 51)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_13_Assignment_1.py
#
# ************************************************************
#
# 52)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_13_Assignment_2.py
#
# ************************************************************
#
# 53)
#
# /storage/emulated/0/LetsUpgrade_Python/Day_13_Assignment_1_Input.ini
#
# ************************************************************
#
#
# Total Dir(s) Found: 0
# Total File(s) Found: 53
